# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4])
print(a.shape)
# Out:
# (4,)

# %%
a = np.array([[1, 2, 3, 4]])
print(a.shape)
# Out:
# (1, 4)

# %%
a = np.array([[1, 2], [3, 4], [5, 6]])
print(a.shape)
# Out:
# (3, 2)

# %%
# How to get a matrix in numpy:
# [[]] - double square brackets
# [[],[]] - 2 rows
# the size of the inside elements is the number of columns
