# %%
import pickle
import numpy as np

# %%
# Load preprocessed dataset
with open("heart_disease_processed.pkl", "rb") as f:
    X_train, X_test, y_train, y_test, scaler = pickle.load(f)

# %%
# Model params
num_features = X_train.shape[1]
num_samples = X_train.shape[0]
W = np.random.randn(num_features)
b = np.random.randn()

X_tr = X_train.to_numpy()
y_tr = y_train.to_numpy()
x_te = X_test.to_numpy()
y_te = y_test.to_numpy()

# %%
# Utils
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def forward_pass(inp, W, b):
    z = np.matmul(inp, W) + b
    a = sigmoid(z)
    return a

def loss_binary_cross_entropy(yh, y):
    loss_vector = -(y * np.log(yh) + (1 - y) * np.log(1 - yh))
    return np.mean(loss_vector)

def calculate_gradients(yh, y_tr, X_tr, num_samples):
    error = yh - y_tr
    dl_dw = (1 / num_samples) * np.matmul(X_tr.T, error)
    dl_db = (1 / num_samples) * np.sum(error)
    return dl_dw, dl_db

# %%
# Training loop
epochs = 1000
lr = 0.1
for epoch in range(epochs):

    yh = forward_pass(X_tr, W, b)

    loss = loss_binary_cross_entropy(yh, y_tr)
    if epoch % 50 == 0:
        print(f"Epoch: {epoch}. Loss: {loss}")

    dl_dw, dl_db = calculate_gradients(yh, y_tr, X_tr, num_samples)

    # update
    W -= lr * dl_dw
    b -= lr * dl_db
# Out:
# Epoch: 0. Loss: 1.1168550838771858
# Epoch: 50. Loss: 0.6985816675073707
# Epoch: 100. Loss: 0.558279859788977
# Epoch: 150. Loss: 0.490983995231054
# Epoch: 200. Loss: 0.45227269700508194
# Epoch: 250. Loss: 0.426143898717457
# Epoch: 300. Loss: 0.4066642006187502
# Epoch: 350. Loss: 0.39144797831771333
# Epoch: 400. Loss: 0.37929218541821147
# Epoch: 450. Loss: 0.36944673812701445
# Epoch: 500. Loss: 0.36138209521479725
# Epoch: 550. Loss: 0.35470408329584713
# Epoch: 600. Loss: 0.34911382124914603
# Epoch: 650. Loss: 0.3443832354367756
# Epoch: 700. Loss: 0.3403376415133271
# Epoch: 750. Loss: 0.33684268621923175
# Epoch: 800. Loss: 0.3337944775919651
# Epoch: 850. Loss: 0.3311121556581195
# Epoch: 900. Loss: 0.3287323264852506
# Epoch: 950. Loss: 0.3266049015616661
